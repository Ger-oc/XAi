# %% [markdown]
# #### <div>
# <img src="https://www.ul.ie/themes/custom/ul/logo.svg" width="350"/>
# </div>
#
#
# ## CS6402  Probabilistic and Explainable AI
# ## SEM2 2024/5
#
# ### CS6402 Assignment 1 - Probability
#
# ### Instructor: Emil Vassev
# Feb 19th, 2025
# <br><br>
# Copyright (C) 2025 - All rights reserved, do not copy or distribute without permission of the author.
# ***

# %% [markdown]
# ## Submission Info
# ### Student Name: <span style="color:red"> Gerard </span>
# ### Student Surname: <span style="color:red">O Connell</span>
# ### Student ID: <span style="color:red">19192118</span>
# ### Date of Final Submission: <span style="color:red">9/3/25</span>
# ***

# %% [markdown]
# # Task #1 (50%)

# %% [markdown]
# ## Introduction
# Suppose you have a bag full of diamonds of different cut, color, clarity. You draw diamonds without replacement.
#
# In this task, you are asked to implement a Python code that will determine the probability of getting diamonds of a specific cut, color and clarity.
#
# ## The Dataset
# The diamonds data can be loaded from the online repository hosted by the seaborn Python library.

# %% [markdown]
# The provided dataset can be loaded as following:

# %%
import seaborn as sns

df = sns.load_dataset('diamonds')

df.head(10)
# Out:
#    carat        cut color clarity  depth  table  price     x     y     z
# 0   0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# 5   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94  3.96  2.48
# 6   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95  3.98  2.47
# 7   0.26  Very Good     H     SI1   61.9   55.0    337  4.07  4.11  2.53
# 8   0.22       Fair     E     VS2   65.1   61.0    337  3.87  3.78  2.49
# 9   0.23  Very Good     H     VS1   59.4   61.0    338  4.00  4.05  2.39

# %% [markdown]
# ## Computing Probability
#
# Use the ```fractions``` library, which provides support for rational number arithmetic. Use the ```compute_probability``` function to calculate probability.
#
# For more information on ```fractions```, please consult the reference page here: https://docs.python.org/3/library/fractions.html#fractions.Fraction

# %%
from fractions import Fraction

cases = len # the number of cases is the length, or size, of a set
favorable = set.intersection # outcomes that are in the event and in the sample space

def compute_probability(event, space): ### The probability of an event, given a sample space.

    result = Fraction(cases(favorable(event, space)), cases(space))
    probability = result.numerator / result.denominator
    
    return probability

# %% [markdown]
# # Step 1: Determine the Sample Space Parameters.  (5%)

# %% [markdown]
# <span style="color:red">TODO</span>
#
# Define the Diamonds Sample Space as:
# * total number of diamonds
# * total number of diamonds in category of cut
# * total number of diamonds in category of color
# * total number of diamonds in category of clarity

# %%
#put your code here
num_diamons = df.shape[0]
print(f"Number of diamonds: {num_diamons}")
# Out:
# Number of diamonds: 53940

# %%
num_cut = df['cut'].count()
print(f"Number of cut: {num_cut}")
# Out:
# Number of cut: 53940

# %%
num_colours = df['color'].count()
print(f"Number of colours: {num_colours}")
# Out:
# Number of colours: 53940

# %%
num_clarity = df['clarity'].count()
print(f"Number of clarity: {num_clarity}")
# Out:
# Number of clarity: 53940

# %% [markdown]
# # Step 2: Implement the Sample Space.  (15%)
#
# <span style="color:red">TODO</span>
#
# Implement a loop that will read the dataframe ```df``` and complete the ```diamonds``` sample space. The sample space must contain strings describing each diamond in the bag in terms of cut, color, and clarity.

# %%
diamonds = []

for index, row in df.iterrows():
    cut = row['cut']
    color = row['color']
    clarity = row['clarity']


    diamond_description = f"Cut: {cut}, Color: {color}, Clarity: {clarity}"
    diamonds.append(diamond_description)

for diamond in diamonds:
    print(diamond)
# Out:
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: VS1
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Good, Color: J, Clarity: SI2
# Cut: Very Good, Color: J, Clarity: VVS2
# Cut: Very Good, Color: I, Clarity: VVS1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Fair, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Good, Color: J, Clarity: SI1
# Cut: Ideal, Color: J, Clarity: VS1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: J, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: I1
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Good, Color: J, Clarity: SI1
# Cut: Good, Color: J, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Very Good, Color: J, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Good, Color: E, Clarity: VS1
# Cut: Good, Color: H, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Ideal, Color: J, Clarity: SI1
# Cut: Good, Color: D, Clarity: VS2
# Cut: Good, Color: D, Clarity: VS1
# Cut: Good, Color: H, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI2
# Cut: Good, Color: H, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: VVS2
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: VVS1
# Cut: Very Good, Color: E, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Good, Color: E, Clarity: VVS1
# Cut: Premium, Color: G, Clarity: VVS1
# Cut: Premium, Color: H, Clarity: VVS1
# Cut: Premium, Color: H, Clarity: VVS1
# Cut: Premium, Color: H, Clarity: VVS2
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Fair, Color: F, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Fair, Color: F, Clarity: VS2
# Cut: Fair, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VVS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VVS1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Good, Color: H, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Very Good, Color: J, Clarity: I1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: I, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Good, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: VS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: F, Clarity: I1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Fair, Color: G, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Very Good, Color: I, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VVS2
# Cut: Good, Color: D, Clarity: VS2
# Cut: Good, Color: G, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Fair, Color: E, Clarity: I1
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Good, Color: F, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: IF
# Cut: Good, Color: G, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: VVS1
# Cut: Premium, Color: H, Clarity: VS1
# Cut: Fair, Color: J, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: IF
# Cut: Premium, Color: I, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: H, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Premium, Color: I, Clarity: IF
# Cut: Premium, Color: H, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: VVS1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Fair, Color: G, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: IF
# Cut: Good, Color: I, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Very Good, Color: I, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: IF
# Cut: Fair, Color: G, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: I1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: I1
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: G, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Fair, Color: E, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Fair, Color: F, Clarity: VS2
# Cut: Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Fair, Color: G, Clarity: I1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Fair, Color: F, Clarity: I1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Fair, Color: J, Clarity: VS2
# Cut: Fair, Color: I, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: I1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Fair, Color: J, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Good, Color: I, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Fair, Color: J, Clarity: VS2
# Cut: Fair, Color: F, Clarity: SI2
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Premium, Color: G, Clarity: I1
# Cut: Very Good, Color: I, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Good, Color: D, Clarity: VS1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: J, Clarity: VS2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: H, Clarity: I1
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Good, Color: F, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: J, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Good, Color: I, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VVS2
# Cut: Good, Color: E, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: J, Clarity: I1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Good, Color: E, Clarity: VS1
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Very Good, Color: I, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: I1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Good, Color: D, Clarity: VS2
# Cut: Premium, Color: H, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: I1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Good, Color: J, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: IF
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Good, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Fair, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: H, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: I1
# Cut: Fair, Color: G, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: I1
# Cut: Good, Color: I, Clarity: I1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Good, Color: H, Clarity: VS2
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Good, Color: H, Clarity: I1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: F, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Fair, Color: D, Clarity: SI2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: J, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: I1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: IF
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Good, Color: G, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Premium, Color: H, Clarity: I1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Fair, Color: J, Clarity: VS2
# Cut: Fair, Color: J, Clarity: VS2
# Cut: Good, Color: J, Clarity: VS2
# Cut: Fair, Color: H, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Good, Color: J, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: I1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Good, Color: G, Clarity: VS2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: J, Clarity: VS1
# Cut: Premium, Color: J, Clarity: VS1
# Cut: Ideal, Color: J, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Good, Color: E, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Good, Color: E, Clarity: VVS2
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Fair, Color: D, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: VS2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Fair, Color: F, Clarity: VS1
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: J, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Premium, Color: D, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Fair, Color: F, Clarity: IF
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Premium, Color: D, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VVS1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: H, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: I1
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Good, Color: I, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Premium, Color: J, Clarity: VS2
# Cut: Premium, Color: H, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Premium, Color: H, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Fair, Color: F, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: IF
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: I1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: IF
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: VVS2
# Cut: Premium, Color: F, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: I, Clarity: I1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: I1
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Fair, Color: H, Clarity: SI1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Good, Color: J, Clarity: SI1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Fair, Color: J, Clarity: VS1
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Good, Color: H, Clarity: VVS1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: E, Clarity: IF
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: J, Clarity: SI2
# Cut: Fair, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Very Good, Color: J, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: H, Clarity: I1
# Cut: Very Good, Color: H, Clarity: IF
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Fair, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Fair, Color: I, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Fair, Color: E, Clarity: SI1
# Cut: Fair, Color: D, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Good, Color: H, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VVS1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Fair, Color: H, Clarity: I1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Good, Color: G, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Premium, Color: G, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: I1
# Cut: Ideal, Color: I, Clarity: I1
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Good, Color: G, Clarity: VVS1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Fair, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: VVS1
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI2
# Cut: Premium, Color: J, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Fair, Color: I, Clarity: SI1
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Fair, Color: I, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: IF
# Cut: Ideal, Color: I, Clarity: IF
# Cut: Ideal, Color: I, Clarity: I1
# Cut: Premium, Color: I, Clarity: I1
# Cut: Good, Color: D, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VVS1
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VVS1
# Cut: Premium, Color: F, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Good, Color: D, Clarity: SI2
# Cut: Good, Color: H, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Fair, Color: I, Clarity: I1
# Cut: Premium, Color: H, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: VVS2
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Very Good, Color: H, Clarity: VVS1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Premium, Color: H, Clarity: VS2
# Cut: Good, Color: F, Clarity: VVS2
# Cut: Very Good, Color: J, Clarity: I1
# Cut: Very Good, Color: F, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Fair, Color: E, Clarity: VS2
# Cut: Good, Color: H, Clarity: I1
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI2
# Cut: Premium, Color: F, Clarity: VS1
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VVS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VVS1
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: SI2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: VS2
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Fair, Color: I, Clarity: SI2
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: SI2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Fair, Color: J, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: IF
# Cut: Good, Color: E, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Good, Color: I, Clarity: SI2
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VVS2
# Cut: Premium, Color: D, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VVS1
# ...
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Good, Color: F, Clarity: SI2
# Cut: Fair, Color: G, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Fair, Color: H, Clarity: VS2
# Cut: Very Good, Color: J, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Fair, Color: E, Clarity: VS2
# Cut: Good, Color: J, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Fair, Color: F, Clarity: SI1
# Cut: Fair, Color: G, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Fair, Color: H, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: SI2
# Cut: Good, Color: J, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VVS1
# Cut: Premium, Color: G, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VVS2
# Cut: Premium, Color: H, Clarity: I1
# Cut: Very Good, Color: E, Clarity: VS1
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Good, Color: E, Clarity: VVS1
# Cut: Fair, Color: E, Clarity: VS2
# Cut: Fair, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: I1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: VVS2
# Cut: Good, Color: G, Clarity: VS2
# Cut: Fair, Color: H, Clarity: VVS2
# Cut: Premium, Color: G, Clarity: I1
# Cut: Good, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: J, Clarity: SI1
# Cut: Good, Color: I, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Fair, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: IF
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Very Good, Color: H, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Good, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Good, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: I, Clarity: VVS1
# Cut: Very Good, Color: I, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: SI2
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: I1
# Cut: Good, Color: F, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Good, Color: F, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Fair, Color: F, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Good, Color: G, Clarity: VS2
# Cut: Premium, Color: I, Clarity: SI2
# Cut: Ideal, Color: J, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VVS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: H, Clarity: VS1
# Cut: Ideal, Color: J, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: H, Clarity: VS1
# Cut: Fair, Color: G, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: VVS2
# Cut: Very Good, Color: I, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Premium, Color: I, Clarity: VS2
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Good, Color: F, Clarity: I1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: VS2
# Cut: Premium, Color: H, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: VVS2
# Cut: Fair, Color: H, Clarity: SI2
# Cut: Premium, Color: J, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Good, Color: J, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Good, Color: F, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VVS2
# Cut: Ideal, Color: E, Clarity: VS2
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Good, Color: F, Clarity: VVS2
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Premium, Color: D, Clarity: VS2
# Cut: Fair, Color: E, Clarity: SI2
# Cut: Premium, Color: H, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Good, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Fair, Color: G, Clarity: I1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: IF
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Good, Color: F, Clarity: VS1
# Cut: Fair, Color: G, Clarity: VS1
# Cut: Fair, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Premium, Color: F, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: G, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Premium, Color: H, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VVS2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: VVS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: E, Clarity: SI2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Good, Color: J, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Very Good, Color: I, Clarity: SI1
# Cut: Premium, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VVS2
# Cut: Fair, Color: I, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: VVS1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: VS2
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS2
# Cut: Very Good, Color: G, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Good, Color: H, Clarity: VVS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Ideal, Color: I, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Premium, Color: E, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VVS2
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Good, Color: D, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Good, Color: H, Clarity: VVS2
# Cut: Very Good, Color: H, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Very Good, Color: D, Clarity: SI2
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: J, Clarity: VS2
# Cut: Ideal, Color: D, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Ideal, Color: H, Clarity: VVS1
# Cut: Ideal, Color: J, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Ideal, Color: D, Clarity: VVS2
# Cut: Premium, Color: D, Clarity: VS1
# Cut: Premium, Color: D, Clarity: SI2
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Fair, Color: I, Clarity: SI2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Very Good, Color: F, Clarity: VS2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: F, Clarity: SI1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Premium, Color: H, Clarity: VS1
# Cut: Very Good, Color: F, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: VS2
# Cut: Very Good, Color: I, Clarity: I1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Fair, Color: G, Clarity: SI2
# Cut: Premium, Color: G, Clarity: VS2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Fair, Color: D, Clarity: VS1
# Cut: Very Good, Color: G, Clarity: VS1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Very Good, Color: I, Clarity: VVS2
# Cut: Good, Color: D, Clarity: VS2
# Cut: Ideal, Color: F, Clarity: IF
# Cut: Premium, Color: G, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Good, Color: E, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: VVS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI1
# Cut: Good, Color: F, Clarity: VS1
# Cut: Ideal, Color: G, Clarity: SI2
# Cut: Good, Color: H, Clarity: I1
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Ideal, Color: H, Clarity: VVS2
# Cut: Ideal, Color: H, Clarity: VS2
# Cut: Premium, Color: E, Clarity: VS1
# Cut: Very Good, Color: E, Clarity: SI2
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: E, Clarity: IF
# Cut: Premium, Color: F, Clarity: VVS1
# Cut: Good, Color: G, Clarity: VS2
# Cut: Good, Color: I, Clarity: VS1
# Cut: Ideal, Color: E, Clarity: SI2
# Cut: Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: J, Clarity: SI1
# Cut: Premium, Color: I, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VVS1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: D, Clarity: VS1
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: VS2
# Cut: Ideal, Color: I, Clarity: SI1
# Cut: Ideal, Color: E, Clarity: SI1
# Cut: Good, Color: F, Clarity: SI1
# Cut: Premium, Color: E, Clarity: SI2
# Cut: Ideal, Color: G, Clarity: VS1
# Cut: Premium, Color: E, Clarity: SI1
# Cut: Premium, Color: F, Clarity: SI1
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Very Good, Color: E, Clarity: VS2
# Cut: Premium, Color: D, Clarity: SI1
# Cut: Ideal, Color: D, Clarity: SI1
# Cut: Good, Color: D, Clarity: SI1
# Cut: Very Good, Color: D, Clarity: SI1
# Cut: Premium, Color: H, Clarity: SI2
# Cut: Ideal, Color: D, Clarity: SI2

# %% [markdown]
# # Step 3: Implement Events and Compute Probabilites.  (30%)

# %% [markdown]
# ## Step 3.1: Compute the Probability of Drawing Five Diamonds with "Ideal" Cut Consecutively?   (10%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with ideal cut"
# * compute the probability of drawing five diamonds with "ideal" cut consecutively and without replacement

# %%
total_diamonds = len(df)
Ideal_diamonds = len(df[df['cut'] == 'Ideal'])
print(f"Total number of diamonds: {Ideal_diamonds}")

probability = 1.0
for i in range (5):
    probability *= (Ideal_diamonds - i) / (total_diamonds - i)
print(f"Probability of drawing five 'Ideal' diamonds consecutively: {probability}")
# Out:
# Total number of diamonds: 21551
# Probability of drawing five 'Ideal' diamonds consecutively: 0.010177975640258418

# %% [markdown]
# ## Step 3.2: Compute the Probability of Drawing Five Diamonds with "SI2" Clarity Consecutively?   (10%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with SI2 clarity"
# * compute the probability of drawing five diamonds with "SI2" clarity consecutively and without replacement

# %%
total_diamonds = len(df)
SI2_diamonds = len(df[df['clarity'] == 'SI2'])
print(f"Total number of diamonds: {total_diamonds}")

probability = 1.0
for i in range (5):
    probability *= (SI2_diamonds - i) / (total_diamonds - i)
print(f"Probability of drawing five Ideal 'SI2' diamonds consecutively: {probability}")
# Out:
# Total number of diamonds: 53940
# Probability of drawing five Ideal 'SI2' diamonds consecutively: 0.00014373941027232868

# %% [markdown]
# ## Step 3.3: Compute the Probability of Drawing Five Diamonds with "E" Color Consecutively?   (5%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with E color"
# * compute the probability of drawing five diamonds with "E" color consecutively and without replacement

# %%
total_diamonds = len(df)
E_diamonds = len(df[df['color'] == 'E'])
print(f"Total number of diamonds: {total_diamonds}")

probability = 1.0
for i in range (5):
    probability *= (E_diamonds - i) / (total_diamonds - i)
print(f"Probability of drawing five Ideal 'SI2' diamonds consecutively: {probability}")
# Out:
# Total number of diamonds: 53940
# Probability of drawing five Ideal 'SI2' diamonds consecutively: 0.00019749130747843014

# %% [markdown]
# ## Step 3.4: Compute the Probability of Drawing Five Diamonds with "Ideal" cut, "SI2" Clarity, and "E" Color Consecutively?   (5%)
#
# <span style="color:red">TODO</span>
#
# * implement the event "diamonds with Ideal cut, SI2 clarity, and E color"
# * compute the probability of drawing five diamonds with "Ideal" cut, "SI2" clarity, and "E" color consecutively and without replacement

# %%
total_diamonds = len(df)
ideal_diamonds = len(df[df['cut'] == 'Ideal'])
si2_diamonds = len(df[df['clarity'] == 'SI2'])
ideal_si2_e_diamonds = len(df[(df['cut'] == 'Ideal') & (df['clarity'] == 'SI2') & (df['color'] == 'E')])


prob_ideal = 1.0
for i in range(5):
    prob_ideal *= (ideal_diamonds - i) / (total_diamonds - i)


prob_si2 = 1.0
for i in range(5):
    prob_si2 *= (si2_diamonds - i) / (total_diamonds - i)


prob_ideal_si2_e = 1.0
for i in range(5):
    prob_ideal_si2_e *= (ideal_si2_e_diamonds - i) / (total_diamonds - i)

print(f"Toatal diamons: {total_diamonds}")
print(f"Probability of drawing five 'Ideal' cut diamonds consecutively: {prob_ideal}")
print(f"Probability of drawing five 'SI2' clarity diamonds consecutively: {prob_si2}")
# If f set to low python rounds up (bankers rounding) rather than truncating the number, remove .16f to get -e number
print(f"Probability of drawing five 'Ideal' cut, 'SI2' clarity, and 'E' color diamonds consecutively: {prob_ideal_si2_e: .16f}")
# Out:
# Toatal diamons: 53940
# Probability of drawing five 'Ideal' cut diamonds consecutively: 0.010177975640258418
# Probability of drawing five 'SI2' clarity diamonds consecutively: 0.00014373941027232868
# Probability of drawing five 'Ideal' cut, 'SI2' clarity, and 'E' color diamonds consecutively:  0.0000000000486520

# %% [markdown]
# # Task #2 (50%)

# %% [markdown]
# ## Introduction
#
# ### Milk Production in Limerick, Ireland
#
# Mr. Collins, an Irish farmer from Limerick, has a herd of 12 dairy cows. He is producing milk daily and measures the litres of milk his cows produce for a month. Below is the milk produced for the last month, per cow.
#
# Milk = [651, 374, 601, 401, 767, 450, 342, 677, 567, 687, 445, 512]
#
# Mr. Collins would like to know how much milk a cow is expected to produce on average.
#
# For this, a statistician friend looks at the county production of milk, considering the entire population of dairy caws in Limerick. In Limerick County, there **125,411** dairy caws with a lowest monthly milk production for a caw of **245** litres and maximum milk production of **878** litres. The monthly milk production is measured in **whole litres**.
#
#
# The statistician decides to use the Bayesian Inference technique where milk is assumed to be normally distributed for the prior and likelihood distributions. For the milk spread in Limerick (normalization factor), the statistician decides to use the uniform distribution.
#
#
# Calculate the posterior milk distribution for Mr. Collins's farm. For the population of dairy caws in Ireland and their milk production per month, use the **numpy.linspace()** method.

# %% [markdown]
# ## Bayesian Inference
#
# Inference - using statistics to deduce properties about a probability distribution from data.
#
# Bayes’ Theorem works not on events but on distributions:
# * Θ - set of parameters
# * P(Θ) - prior distribution, or distribution of our belief about the true value of Θ
# * P(Θ|data) - posterior distribution, or distribution of our belief about Θ after we have taken the observed data into account
# * P(data|Θ) - likelihood distribution measures the degree to which data supports Θ
# * P(data) - normalization distribution, i.e., is the total probability of the data taking into account all possible hypotheses
# <pre>
#               P(data|Θ) * P(Θ)
#    P(Θ|data) = -----------------
# 		          P(data)
# </pre>

# %% [markdown]
# ## Your Solution to Task #2 (50%)

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# Data
milk_production = np.array([651, 374, 601, 401, 767, 450, 342, 677, 567, 687, 445, 512])
mu_prior = np.mean(milk_production)
sigma_prior = np.std(milk_production, ddof=1)

# Limerick data
county_min = 245
county_max = 878
population_size = 125411

prior_distribution = stats.norm(mu_prior, sigma_prior)
likelihood_distribution = stats.norm(mu_prior, sigma_prior)
x_values = np.linspace(county_min, county_max, population_size)

posterior_values = prior_distribution.pdf(x_values) * likelihood_distribution.pdf(x_values)
posterior_values /= posterior_values.sum()
posterior_mean = np.sum(x_values * posterior_values)

# Rounding as the answer is a decimal place and the question says whole liters
posterior_mean_rounded = int(round(posterior_mean))

print(f"Posterior expected milk production per cow: {posterior_mean_rounded} litres")

# Plot colours made for dark mode IDE, not tested in light mode with white screen
plt.figure(figsize=(10, 6))
plt.plot(x_values, posterior_values, label='Posterior Distribution', color='blue')
plt.axvline(posterior_mean, color='red', linestyle='dashed', label=f'Posterior Mean: {posterior_mean}')
plt.title("Posterior Milk Production Distribution")
plt.xlabel("Milk Production (litres)")
plt.ylabel("Probability Density")
plt.legend()
plt.grid()
plt.show()
# Out:
# Posterior expected milk production per cow: 540 litres
